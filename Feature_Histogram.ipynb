# %%
# Import required libraries
import numpy as np
import pandas as pd
import hvplot.pandas
from pathlib import Path
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
# Make a reference to the comic_books_expanded.csv file path
csv_path = "Data/data.csv"

# Import the data.csv file as a DataFrame
df = pd.read_csv(csv_path, encoding="utf-8",
                   sep = ';',
                   engine = 'python')

df.head(5)
# Out:
#    Marital status  Application mode  Application order  Course  \
# 0               1                17                  5     171
# 1               1                15                  1    9254
# 2               1                 1                  5    9070
# 3               1                17                  2    9773
# 4               2                39                  1    8014
#
#    Daytime/evening attendance\t  Previous qualification  \
# 0                             1                       1
# 1                             1                       1
# 2                             1                       1
# 3                             1                       1
# 4                             0                       1
#
#    Previous qualification (grade)  Nacionality  Mother's qualification  \
# 0                           122.0            1                      19
# 1                           160.0            1                       1
# ...

# %%
df=df.rename(columns={'Daytime/evening attendance\t':'Daytime evening attendance'})

# %%
all_columns=df.columns.values
all_columns
# Out:
# array(['Marital status', 'Application mode', 'Application order',
#        'Course', 'Daytime evening attendance', 'Previous qualification',
#        'Previous qualification (grade)', 'Nacionality',
#        "Mother's qualification", "Father's qualification",
#        "Mother's occupation", "Father's occupation", 'Admission grade',
#        'Displaced', 'Educational special needs', 'Debtor',
#        'Tuition fees up to date', 'Gender', 'Scholarship holder',
#        'Age at enrollment', 'International',
#        'Curricular units 1st sem (credited)',
#        'Curricular units 1st sem (enrolled)',
#        'Curricular units 1st sem (evaluations)',
#        'Curricular units 1st sem (approved)',
#        'Curricular units 1st sem (grade)',
#        'Curricular units 1st sem (without evaluations)',
#        'Curricular units 2nd sem (credited)',
#        'Curricular units 2nd sem (enrolled)',
#        'Curricular units 2nd sem (evaluations)',
# ...

# %%
df.hist(column='Marital status')
plt.savefig('Figure/Marital status.png')

# %%
df.hist(column='Application mode')
plt.savefig('Figure/Application mode.png')

# %%
df.hist(column='Application order')
plt.savefig('Figure/Application order.png')

# %%
df.hist(column='Course')
plt.savefig('Figure/Course.png')

# %%
df.hist(column='Daytime evening attendance')
plt.savefig('Figure/Daytime evening attendance.png')

# %%
df.hist(column='Previous qualification')
plt.savefig('Figure/Previous qualification.png')

# %%
df.hist(column='Previous qualification (grade)')
plt.savefig('Figure/Previous qualification (grade).png')

# %%
df.hist(column='Nacionality')
plt.savefig('Figure/Nacionality.png')

# %%
df.hist(column="Mother's qualification")
plt.savefig("Figure/Mother's qualification.png")

# %%
df.hist(column="Father's qualification")
plt.savefig("Figure/Father's qualification.png")

# %%
df.hist(column="Mother's occupation")
plt.savefig("Figure/Mother's occupation.png")

# %%
df.hist(column="Father's occupation")
plt.savefig("Figure/Father's occupation.png")

# %%
df.hist(column="Admission grade")
plt.savefig("Figure/Admission grade.png")

# %%
df.hist(column="Displaced")
plt.savefig("Figure/Displaced.png")

# %%
df.hist(column="Educational special needs")
plt.savefig("Figure/Educational special needs.png")

# %%
df.hist(column="Debtor")
plt.savefig("Figure/Debtor.png")

# %%
df.hist(column="Tuition fees up to date")
plt.savefig("Figure/Tuition fees up to date.png")

# %%
df.hist(column="Gender")
plt.savefig("Figure/Gender.png")

# %%
df.hist(column="Scholarship holder")
plt.savefig("Figure/Scholarship holder.png")

# %%
df.hist(column="Age at enrollment")
plt.savefig("Figure/Age at enrollment.png")

# %%
df.hist(column="International")
plt.savefig("Figure/International.png")

# %%
df.hist(column="Curricular units 1st sem (credited)")
plt.savefig("Figure/Curricular units 1st sem (credited).png")

# %%
df.hist(column="Curricular units 2nd sem (credited)")
plt.savefig("Figure/Curricular units 2nd sem (credited).png")

# %%
df.hist(column="Curricular units 1st sem (enrolled)")
plt.savefig("Figure/Curricular units 1st sem (enrolled).png")

# %%
df.hist(column="Curricular units 2nd sem (enrolled)")
plt.savefig("Figure/Curricular units 2nd sem (enrolled).png")

# %%
df.hist(column="Curricular units 1st sem (evaluations)")
plt.savefig("Figure/Curricular units 1st sem (evaluations).png")

# %%
df.hist(column="Curricular units 2nd sem (evaluations)")
plt.savefig("Figure/Curricular units 2nd sem (evaluations).png")

# %%
df.hist(column="Curricular units 1st sem (approved)")
plt.savefig("Figure/Curricular units 1st sem (approved).png")

# %%
df.hist(column="Curricular units 2nd sem (approved)")
plt.savefig("Figure/Curricular units 2nd sem (approved).png")

# %%
df.hist(column="Curricular units 1st sem (grade)")
plt.savefig("Figure/Curricular units 1st sem (grade).png")

# %%
df.hist(column="Curricular units 2nd sem (grade)")
plt.savefig("Figure/Curricular units 2nd sem (grade).png")

# %%
df.hist(column="Curricular units 1st sem (without evaluations)")
plt.savefig("Figure/Curricular units 1st sem (without evaluations).png")

# %%
df.hist(column="Curricular units 2nd sem (without evaluations)")
plt.savefig("Figure/Curricular units 2nd sem (without evaluations).png")

# %%
df.hist(column="Unemployment rate")
plt.savefig("Figure/Unemployment rate.png")

# %%
df.hist(column="Inflation rate")
plt.savefig("Figure/Inflation rate.png")

# %%
df.hist(column="GDP")
plt.savefig("Figure/GDP.png")
